# %%
from numpy import random;
import numpy as np;
b=random.randint(20, size=(15))
c = b.reshape(3,5)
print(c)
print(c.shape)
new_a = np.where(c == [
   [i]
   for i in np.amax(c, axis = 1)
], 0 ,c)
print(new_a)
# Out:
# [[17 13  6  6  0]
#  [ 9 15 18 18 12]
#  [15 12  7 14  0]]
# (3, 5)
# [[ 0 13  6  6  0]
#  [ 9 15  0  0 12]
#  [ 0 12  7 14  0]]

# %%
import pandas as pd

dfv=pd.read_csv("data.csv")
mean_value=df['Calories'].mean()
dfv['Calories'].fillna(value=mean_value,inplace=True)
dfv.head(25)
dfv.Duration.describe()
dfv.Pulse.describe()
dfv[(dfv['Calories']>500) & (dfv['Calories']<1000)]
dfv[(dfv['Calories']>500 & (dfv['Pulse']<100))]
df_modified=dfv.drop("Maxpulse",axis=1)
df_modified
dfv=dfv.drop("Maxpulse",axis=1)
dfv
dfv['Calories']=dfv['Calories'].astype(int)
dfv.dtypes
dfv.plot.scatter( x = 'Duration', y = 'Calories')
# Out:
# <AxesSubplot: xlabel='Duration', ylabel='Calories'>

# %%
import matplotlib.pyplot as plt

programming_languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'

language_popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]

explode = (0.1, 0, 0, 0,0,0)

plt.pie(popuratity, explode=explode, labels=languages, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
